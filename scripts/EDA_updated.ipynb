# %%
# Importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
file_path = '/Users/shlokkamat/Documents/Documents - Shlok’s MacBook Pro/GitHub/NUS_Proj/SHAP/data/train.csv'
data = pd.read_csv(file_path)

# %%
# Data Cleaning: Drop irrelevant columns for analysis
data_cleaned = data.drop(columns=["Unnamed: 0", "id"])

# %%
# Exploratory Data Analysis
# 1. Missing Values
missing_values = data_cleaned.isnull().sum()
print("Missing Values:")
print(missing_values)
# Out:
# Missing Values:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# ...

# %%
# 2. Class Distribution in Target Variable
class_distribution = data_cleaned["satisfaction"].value_counts()
print("\nClass Distribution:")
print(class_distribution)
# Out:
# Class Distribution:
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: satisfaction, dtype: int64

# %%
# 3. Visualization: Distribution of Numerical Features
numerical_columns = data_cleaned.select_dtypes(include=["int64", "float64"]).columns
data_cleaned[numerical_columns].hist(figsize=(15, 10), bins=30)
plt.suptitle("Distribution of Numerical Features", fontsize=16)
plt.tight_layout()
plt.show()

# %%
# 4. Correlation Heatmap
plt.figure(figsize=(12, 8))
correlation_matrix = data_cleaned[numerical_columns].corr()
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap of Numerical Features")
plt.show()

# %%
# 5. Categorical Feature Analysis
categorical_columns = data_cleaned.select_dtypes(include=["object"]).columns
for column in categorical_columns:
    plt.figure(figsize=(8, 5))
    sns.countplot(data=data_cleaned, x=column, hue="satisfaction", palette="viridis")
    plt.title(f"Distribution of {column} by Satisfaction")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
